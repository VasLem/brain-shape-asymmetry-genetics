# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
scipy.io.loadmat()
data_dict = mat73.loadmat('../SAMPLE_DATA/asym_data.mat')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/code/.venv/lib/python3.8/site-packages/mat73/__init__.py in loadmat(filename, verbose)
#     138     try:
# --> 139         with h5py.File(filename, 'r') as hdf5:
#     140             dictionary = decoder.mat2dict(hdf5)
#
# ~/code/.venv/lib/python3.8/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     405                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
#
# ~/code/.venv/lib/python3.8/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     172             flags |= h5f.ACC_SWMR_READ
# ...

# %%
data_dict
# Out:
# {'Region': {'AlignedShapes': array([[[-0.13996895, -0.06855476, -0.14492358, ..., -0.05405271,
#            -0.15884475, -0.10527918],
#           [-0.9209353 , -0.82100314, -0.8490177 , ..., -0.9004763 ,
#            -0.85884094, -0.8576534 ],
#           [ 0.610019  ,  0.69784147,  0.6725262 , ...,  0.7218189 ,
#             0.6483233 ,  0.72045755]],
#
#          [[-0.3782216 , -0.2887971 , -0.39804748, ..., -0.41116002,
#            -0.36908436, -0.429312  ],
#           [-0.8109157 , -0.83241946, -0.78976095, ..., -0.8484506 ,
#            -0.82725227, -0.73862433],
#           [ 1.267899  ,  1.2049754 ,  1.2807915 , ...,  1.2552973 ,
#             1.2772794 ,  1.4213778 ]],
#
#          [[-1.0473251 , -1.0526667 , -0.93129474, ..., -0.9596606 ,
#            -1.0143374 , -1.0089676 ],
#           [-0.19105639, -0.14264321, -0.09340087, ..., -0.12402692,
#            -0.16847534, -0.24070877],
#           [ 0.83009946,  0.94346434,  0.777677  , ...,  0.9737046 ,
# ...
